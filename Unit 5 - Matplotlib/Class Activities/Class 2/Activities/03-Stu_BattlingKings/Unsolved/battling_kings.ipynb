# %%
# Dependencies
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %%
# Read CSV
got = pd.read_csv("Resources/got.csv")
got
# Out:
#                                                  name  year  battle_number  \
# 0                          Battle of the Golden Tooth   298              1
# 1                         Battle at the Mummer's Ford   298              2
# 2                                  Battle of Riverrun   298              3
# 3                            Battle of the Green Fork   298              4
# 4                       Battle of the Whispering Wood   298              5
# 5                                 Battle of the Camps   298              6
# 6                                       Sack of Darry   298              7
# 7                               Battle of Moat Cailin   299              8
# 8                            Battle of Deepwood Motte   299              9
# 9                           Battle of the Stony Shore   299             10
# 10                         Battle of Torrhen's Square   299             11
# ...

# %%
# Get attacker and defender data
attacker_data = got["attacker_king"].value_counts()
defender_data = got["defender_king"].value_counts()

# %%
# Get total battle data
gotyou = attacker_data.add(defender_data, fill_value = 0)

# %%
# Configure plot and ticks

got.plot(kind = "bar", facecolor = "red")

# %%
# Set textual properties
plt.title("The Bloodthirst of Kings")
plt.ylabel("Number of Battles Participated In")
plt.xlabel("King")
# Out:
# Text(0.5, 0, 'King')

# %%
# Show plot
plt.show()
